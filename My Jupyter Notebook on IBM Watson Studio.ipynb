# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Juan Martínez**
# Data Scientist

# %% [markdown]
# *I am interested in data science because I recognize the power of data and the bright future we can create using them in a responsible and ethical way.*

# %% [markdown]
# ### The following code is performing a simple operation and explaining the result:

# %%
x = 1
y = 2
if (x + y) == 3:
    print("The sum of x and y is 3")
# Out:
# The sum of x and y is 3

# %% [markdown]
# ***
#
# Here is an horizontal rule
#
# ***
#
# * This is a bullet list
# * This is a bullet list
# * This is a bullet list
#
# `Here is some code: print("Hello World")`
#
# If you don't know something, you can <a href="http://google.com" target="_blank">google it</a>
